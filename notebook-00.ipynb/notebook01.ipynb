# %%
from langchain_ollama import ChatOllama

# %%
llm = ChatOllama(
    model="qwen2.5:1.5b",
    temperature=0.7
)

# %%
response = llm.invoke("What is RAG")
type(response)

# %%
#decorator
def simple_func():
 print("some actions")

# %%
def my_decorator():
    def inner_function():
    print("somenew functionality")
